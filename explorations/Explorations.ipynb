# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.gold;

# %%
select * from workspace.silver.silver_products;

# %%
# Assume we have an existimg gold layer customer table from the previous processes 

df = spark.sql("select * from fmcg.gold.dim_gross_price")
df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("delta.enableChangeDataFeed", "true") \
    .option("mergeSchema", "true") \
    .saveAsTable("workspace.gold.dim_price")


# Now we want to add a new column to the table

# %%
# %sql
select * from workspace.gold.dim_products;

# %%
# %sql
select * from workspace.gold.dim_customers

# %%
# %sql
select count(*) from workspace.gold.dim_customers;

# %%
# %sql

select count(*) from workspace.gold.sb_dim_customers;

# %%
# %sql

-- create a catalog and schema for development purpose

--create catalog dev;
create schema dev.bronze;

# %%
# %sql
create table dev.bronze.customers
as
select * from 
read_files(
  '/Volumes/pysparkdbt_catalog/source/source_data/customers/',
  header => True,
  inferSchema => True,
  format => 'csv'
)

# %%
# %sql
describe extended dev.bronze.customers;

# %%
# %sql
select * from dev.bronze.customers;

# %%
# %sql
-- Disable deletionvector table propery 
ALTER TABLE dev.bronze.customers SET TBLPROPERTIES(delta.enableDeletionVectors = TRUE);

# %%
# %sql 
-- delete the data without deletion vecto
delete from dev.bronze.customers 
where lower(first_name) = 'carl';

# %%
# %sql
describe history dev.bronze.customers;

# %%
# %sql
-- OPTIMIZE dev.bronze.customers;
    
select * from dev.bronze.customers;

# %% [markdown]
# Liquid Clustering

# %%
# %sql
alter table dev.bronze.customers cluster by none;

# %%
# %sql 
describe history dev.bronze.customers;
